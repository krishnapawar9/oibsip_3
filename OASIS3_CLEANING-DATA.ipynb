# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df = pd.read_csv("oasis_3.csv")

# %%
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
df.head(10)
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
# 5  5099         Large Cozy 1 BR Apartment In Midtown East     7322
# 6  5121                                   BlissArtsSpace!     7356
# 7  5178                  Large Furnished Room Near B'way      8967
# 8  5203                Cozy Clean Guest Room - Family Apt     7490
# 9  5238                Cute & Cozy Lower East Side 1 bdrm     7549
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0         John            Brooklyn          Kensington  40.64749  -73.97237
# ...

# %%
df.tail(10)
# Out:
#              id                                               name    host_id  \
# 48885  36482809    Stunning Bedroom NYC! Walking to Central Park!!  131529729
# 48886  36483010                    Comfy 1 Bedroom in Midtown East  274311461
# 48887  36483152    Garden Jewel Apartment in Williamsburg New York  208514239
# 48888  36484087  Spacious Room w/ Private Rooftop, Central loca...  274321313
# 48889  36484363                                 QUIT PRIVATE HOUSE  107716952
# 48890  36484665    Charming one bedroom - newly renovated rowhouse    8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg    6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood   23492952
# 48893  36485609               43rd St. Time Square-cozy single bed   30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen   68119814
#
#            host_name neighbourhood_group       neighbourhood  latitude  \
# ...

# %%
df.shape
# Out:
# (48895, 16)

# %%
df.size
# Out:
# 782320

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
df.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %% [markdown]
# ### Datatype formatting

# %%
df['last_review'] = pd.to_datetime(df['last_review'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %% [markdown]
# ### Treating Null values

# %%
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
df.isnull()
# Out:
#           id   name  host_id  host_name  neighbourhood_group  neighbourhood  \
# 0      False  False    False      False                False          False
# 1      False  False    False      False                False          False
# 2      False  False    False      False                False          False
# 3      False  False    False      False                False          False
# 4      False  False    False      False                False          False
# ...      ...    ...      ...        ...                  ...            ...
# 48890  False  False    False      False                False          False
# 48891  False  False    False      False                False          False
# 48892  False  False    False      False                False          False
# 48893  False  False    False      False                False          False
# 48894  False  False    False      False                False          False
#
# ...

# %%
df.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df["reviews_per_month"].mean()
# Out:
# np.float64(1.3732214298586618)

# %%
df["reviews_per_month"].fillna(0,inplace=True)
# Out:
# C:\Users\krishna\AppData\Local\Temp\ipykernel_10656\2635581885.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["reviews_per_month"].fillna(0,inplace=True)

# %%
df.dropna(subset=["name","host_name"],inplace=True)

# %%
df.isnull().sum()
# Out:
# id                                    0
# name                                  0
# host_id                               0
# host_name                             0
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10037
# reviews_per_month                     0
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
df["last_review"].median()
# Out:
# Timestamp('2019-05-19 00:00:00')

# %%
df["last_review"].mode()
# Out:
# 0   2019-06-23
# Name: last_review, dtype: datetime64[ns]

# %%
df["last_review"].mean()
# Out:
# Timestamp('2018-10-04 07:23:47.072976128')

# %%
df["last_review"].describe()
# Out:
# count                            38821
# mean     2018-10-04 07:23:47.072976128
# min                2011-03-28 00:00:00
# 25%                2018-07-09 00:00:00
# 50%                2019-05-19 00:00:00
# 75%                2019-06-23 00:00:00
# max                2019-07-08 00:00:00
# Name: last_review, dtype: object

# %%
sns.heatmap(df.corr(numeric_only = True))
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %% [markdown]
# ### check for duplicates

# %%
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, name, host_id, host_name, neighbourhood_group, neighbourhood, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []

# %% [markdown]
# ### check for outliers and handling them

# %%
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
sns.boxplot(df["neighbourhood_group"])
# Out:
# <Axes: ylabel='neighbourhood_group'>

# %%
df[df["neighbourhood_group"].isin(["Staten Island"])]
# Out:
#              id                                               name    host_id  \
# 169       42882                          New York room with a view     185978
# 249       62452                     A SpeciaL!! Private Room in NY     303939
# 250       62461                        B NYC Staten Alternative...     303939
# 251       62787                        C Private Room By The Ferry     303939
# 256       63320                 D Private Che@p Room 2 Explore NYC     303939
# ...         ...                                                ...        ...
# 48441  36267546                              A Home Away From Home  233485864
# 48446  36270376     Beautiful home on Staten Island, walk to ferry     444904
# 48533  36310353  Staten Island Resort minutes from ferry! Amazi...   28586423
# 48649  36355110     PRIVATE ROOM IN STATEN ISLAND -FOR LADIES ONLY  201187671
# 48799  36438336                                    Seas The Moment  211644523
#
# ...

# %%
df[df["neighbourhood_group"].isin(["Bronx"])]
# Out:
#              id                                               name    host_id  \
# 171       44096                                   Room with a View     190409
# 207       54626                     Cozy bedroom by Yankee Stadium     190409
# 260       63588                                                LL3     295128
# 261       63610   DOMINIQUE'S NY mini efficiency* wifi*metro*quiet     310670
# 309       71812               Condo Apartment with laundry in unit     369015
# ...         ...                                                ...        ...
# 48783  36426093                                   Best room in nyc  273877318
# 48792  36428186                            Private house Apartment  141511069
# 48795  36429652        Cute double room for the perfect Yankee fan   58222366
# 48796  36435986  1A. Studio & Stay. 30 minutes to Midtown Manha...   37678939
# 48805  36442252                      1B-1B apartment near by Metro  273841667
#
# ...

# %%
sns.boxplot(df["latitude"])
# Out:
# <Axes: ylabel='latitude'>

# %%
sns.scatterplot(df["latitude"])
# Out:
# <Axes: ylabel='latitude'>

# %%
sns.scatterplot(df["longitude"])
# Out:
# <Axes: ylabel='longitude'>

# %%
sns.boxplot(df["price"])
# Out:
# <Axes: ylabel='price'>

# %%
sns.scatterplot(df["price"])
# Out:
# <Axes: ylabel='price'>

# %%
df["price"].min()
# Out:
# np.int64(0)

# %%
df["price"].max()
# Out:
# np.int64(10000)

# %%
df[df["price"] >= 2000]
# Out:
#              id                                           name    host_id  \
# 496      174966          Luxury 2Bed/2.5Bath Central Park View     836168
# 946      363673               Beautiful 3 bedroom in Manhattan     256239
# 1480     664047            Lux 2Bed/2.5Bath Central Park Views     836168
# 1862     826690               Sunny, Family-Friendly 2 Bedroom    4289240
# 2018     893413     Architecturally Stunning Former Synagogue!    4751930
# ...         ...                                            ...        ...
# 46533  35297214                      Amazing Chelsea 4BR Loft!  256649546
# 46614  35345358                 Northside Williamsburg Stunner     956324
# 47350  35706068                               wait until later   35741633
# 48043  36056808   Luxury TriBeCa Apartment at an amazing price  271248669
# 48304  36189195  Next to Times Square/Javits/MSG! Amazing 1BR!  270214015
#
#       host_name neighbourhood_group     neighbourhood  latitude  longitude  \
# ...

# %%
df = df.drop(df[df["price"] > 2000].index)

# %%
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
sns.scatterplot(df["price"])
# Out:
# <Axes: ylabel='price'>

# %% [markdown]
# ### EDA

# %%
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
sns.countplot(df["neighbourhood_group"])
# Out:
# <Axes: xlabel='count', ylabel='neighbourhood_group'>

# %%
sns.countplot(df["room_type"])
# Out:
# <Axes: xlabel='count', ylabel='room_type'>

# %% [markdown]
# ## COUNT OF:
#
# ### ENTIRE HOME/APT = 25322
# ### PRIVATE ROOM =  22291
# ### SHARED ROOM = 1159

# %%
df["room_type"].describe()
# Out:
# count               48772
# unique                  3
# top       Entire home/apt
# freq                25322
# Name: room_type, dtype: object

# %%
df[df["room_type"] == "Private room"]
# Out:
#              id                                               name    host_id  \
# 0          2539                 Clean & quiet apt home by the park       2787
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !       4632
# 6          5121                                    BlissArtsSpace!       7356
# 7          5178                   Large Furnished Room Near B'way        8967
# 8          5203                 Cozy Clean Guest Room - Family Apt       7490
# ...         ...                                                ...        ...
# 48888  36484087  Spacious Room w/ Private Rooftop, Central loca...  274321313
# 48889  36484363                                 QUIT PRIVATE HOUSE  107716952
# 48890  36484665    Charming one bedroom - newly renovated rowhouse    8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg    6570630
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen   68119814
#
# ...

# %%
df[df["room_type"] == "Shared room"]
# Out:
#              id                                             name    host_id  \
# 39        12048              LowerEastSide apt share shortterm 1       7549
# 203       54453               MIDTOWN WEST - Large alcove studio     255583
# 357       99070              Comfortable Cozy Space in El Barrio     522065
# 492      173072                    Cozy Pre-War Harlem Apartment     826192
# 545      200645                   Best Manhattan Studio Deal!        933378
# ...         ...                                              ...        ...
# 48832  36450814                         FLATBUSH HANG OUT AND GO  267223765
# 48855  36456829                Perfectly Located Organic Getaway    6677425
# 48867  36473044  The place you were dreaming for.(only for guys)  261338177
# 48868  36473253                     Heaven for you(only for guy)  261338177
# 48893  36485609             43rd St. Time Square-cozy single bed   30985759
#
# ...

# %%
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
Top_price_based = df.sort_values(by="price",ascending=False)

# %%
Top_price_based[Top5_price_based["price"]==2000]
# Out:
#              id                                               name    host_id  \
# 7477    5578843                  Private cozy Bedroom in Brooklyn    26098783
# 7485    5582283                Cozy bedroom in Brooklyn Sunsetpark   26098783
# 7513    5616298                Lux 2Bed/2.5Bath Central Park View!     836168
# 19474  15537258                                   889 Bushwick Ave   74442807
# 8915    6833395                        Amazing panoramic view loft   10767841
# 16545  13250484   Beautiful 2000 sq. ft. loft in Hells Kitchen NYC   10196579
# 3622    2169765                          Lower Park Avenue Pre War    8258307
# 19270  15347268  Modern Luxury 2 Bed/ 2 Bath apartment in Midtown!     836168
# 22976  18610554  Private bedroom, Queenbed on suite bath and cl...    7055854
# 44429  34221161                 Room with sofa bed or air mattress    9295237
# 3598    2150727                1500 sq ft apt sleeps 8 - SuperBowl    5579700
# ...

# %%
Top5_price_based = Top_price_based.head()

# %%
Top5_price_based
# Out:
#              id                                 name   host_id host_name  \
# 7477    5578843    Private cozy Bedroom in Brooklyn   26098783       Sam
# 7485    5582283  Cozy bedroom in Brooklyn Sunsetpark  26098783       Sam
# 7513    5616298  Lux 2Bed/2.5Bath Central Park View!    836168     Henry
# 19474  15537258                     889 Bushwick Ave  74442807      Sean
# 8915    6833395          Amazing panoramic view loft  10767841     Manon
#
#       neighbourhood_group    neighbourhood  latitude  longitude  \
# 7477             Brooklyn      Sunset Park  40.65137  -74.00666
# 7485             Brooklyn      Sunset Park  40.65118  -74.00842
# 7513            Manhattan  Upper West Side  40.77470  -73.98708
# 19474            Brooklyn         Bushwick  40.69477  -73.92611
# 8915            Manhattan  Lower East Side  40.71321  -73.99099
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# ...
